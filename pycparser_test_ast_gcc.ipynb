# %%
import sys
from pycparser import parse_file

filename = 'c-files/memmgr.c'

ast = parse_file(filename, use_cpp=True,
        cpp_path='gcc',
        cpp_args=['-E', r'-Iutils/fake_libc_include'])

ast.show(showcoord=True, attrnames=True)
# Out:
# FileAST:  (at None)
#   Typedef: name=byte, quals=[], storage=['typedef'] (at c-files/memmgr.h:72)
#     TypeDecl: declname=byte, quals=[] (at c-files/memmgr.h:72)
#       IdentifierType: names=['unsigned', 'char'] (at c-files/memmgr.h:72)
#   Typedef: name=ulong, quals=[], storage=['typedef'] (at c-files/memmgr.h:73)
#     TypeDecl: declname=ulong, quals=[] (at c-files/memmgr.h:73)
#       IdentifierType: names=['unsigned', 'long'] (at c-files/memmgr.h:73)
#   Decl: name=memmgr_init, quals=[], storage=[], funcspec=[] (at c-files/memmgr.h:80)
#     FuncDecl:  (at c-files/memmgr.h:80)
#       TypeDecl: declname=memmgr_init, quals=[] (at c-files/memmgr.h:80)
#         IdentifierType: names=['void'] (at c-files/memmgr.h:80)
#   Decl: name=memmgr_alloc, quals=[], storage=[], funcspec=[] (at c-files/memmgr.h:84)
#     FuncDecl:  (at c-files/memmgr.h:84)
#       ParamList:  (at c-files/memmgr.h:84)
#         Decl: name=nbytes, quals=[], storage=[], funcspec=[] (at c-files/memmgr.h:84)
# ...
